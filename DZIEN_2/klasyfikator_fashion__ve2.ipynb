# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
class_names = ['T-shrit/Top','Trousers','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
#budowa modelu sieci neuronowej
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images,train_labels,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4977 - accuracy: 0.8254
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3723 - accuracy: 0.8656
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3345 - accuracy: 0.8770
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3111 - accuracy: 0.8853
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2925 - accuracy: 0.8913
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2801 - accuracy: 0.8968
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2667 - accuracy: 0.9014
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2556 - accuracy: 0.9059
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2459 - accuracy: 0.9080
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2383 - accuracy: 0.9115

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels,verbose=2)
print(f'Test modelu -> accuracy: {test_acc}, loss: {test_loss}')
# Out:
# 313/313 - 1s - loss: 0.3326 - accuracy: 0.8861 - 654ms/epoch - 2ms/step
# Test modelu -> accuracy: 0.8860999941825867, loss: 0.33261558413505554
